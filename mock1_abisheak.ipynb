# %% [markdown]
# #                                                           Multilingual Mobile App Reviews Dataset Analysis

# %% [markdown]
# # column description

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('multilingual_mobile_app_reviews_2025.csv')
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating          review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09 19:26:40               True  Android Tablet
# 1        1.6  2024-06-21 17:29:40               True            iPad
# 2        3.6  2024-10-31 13:47:12               True            iPad
# 3        3.8  2025-03-12 06:16:22               True             iOS
# 4        3.2  2024-04-21 03:48:27               True            iPad
# ...      ...                  ...                ...             ...
# 2509     3.0  2023-11-23 01:07:30              False             iOS
# 2510     1.9  2025-06-05 16:42:20               True   Windows Phone
# 2511     3.4  2024-06-15 05:02:18               True  Android Tablet
# 2512     2.7  2023-12-02 01:41:31               True         Android
# 2513     2.1  2025-03-04 02:51:17               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  app_version
# 0                    65      14.0        China             Female          1.4
# 1                   209      18.0      Germany               Male          8.9
# 2                   163      67.0      Nigeria               Male  2.8.37.5926
# 3                   664      66.0        India             Female         10.2
# 4                  1197      40.0  South Korea  Prefer not to say          4.7
# ...                 ...       ...          ...                ...          ...
# 2509                635      21.0     Malaysia         Non-binary   1.1.2-beta
# 2510               1127      38.0   Bangladesh                NaN     v12.0.80
# 2511                677      27.0     Pakistan                NaN  9.1.32.4821
# 2512                155      35.0        India                NaN      v8.9.13
# 2513               1040      26.0   Bangladesh  Prefer not to say          2.2
#
# [2514 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review_id          2514 non-null   int64
#  1   user_id            2514 non-null   int64
#  2   app_name           2514 non-null   object
#  3   app_category       2514 non-null   object
#  4   review_text        2455 non-null   object
#  5   review_language    2514 non-null   object
#  6   rating             2477 non-null   float64
#  7   review_date        2514 non-null   object
#  8   verified_purchase  2514 non-null   bool
#  9   device_type        2514 non-null   object
#  10  num_helpful_votes  2514 non-null   int64
#  11  user_age           2514 non-null   float64
#  12  user_country       2473 non-null   object
#  13  user_gender        1927 non-null   object
#  14  app_version        2484 non-null   object
# dtypes: bool(1), float64(2), int64(3), object(9)
# memory usage: 277.6+ KB

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df['review_id']
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating          review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09 19:26:40               True  Android Tablet
# 1        1.6  2024-06-21 17:29:40               True            iPad
# 2        3.6  2024-10-31 13:47:12               True            iPad
# 3        3.8  2025-03-12 06:16:22               True             iOS
# 4        3.2  2024-04-21 03:48:27               True            iPad
# ...      ...                  ...                ...             ...
# 2509     3.0  2023-11-23 01:07:30              False             iOS
# 2510     1.9  2025-06-05 16:42:20               True   Windows Phone
# 2511     3.4  2024-06-15 05:02:18               True  Android Tablet
# 2512     2.7  2023-12-02 01:41:31               True         Android
# 2513     2.1  2025-03-04 02:51:17               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  app_version
# 0                    65      14.0        China             Female          1.4
# 1                   209      18.0      Germany               Male          8.9
# 2                   163      67.0      Nigeria               Male  2.8.37.5926
# 3                   664      66.0        India             Female         10.2
# 4                  1197      40.0  South Korea  Prefer not to say          4.7
# ...                 ...       ...          ...                ...          ...
# 2509                635      21.0     Malaysia         Non-binary   1.1.2-beta
# 2510               1127      38.0   Bangladesh                NaN     v12.0.80
# 2511                677      27.0     Pakistan                NaN  9.1.32.4821
# 2512                155      35.0        India                NaN      v8.9.13
# 2513               1040      26.0   Bangladesh  Prefer not to say          2.2
#
# [2514 rows x 15 columns]

# %%
df['review_id'].unique()
# Out:
# array([   1,    2,    3, ..., 2512, 2513, 2514], shape=(2514,))

# %%
df.query("app_name == 'WhatsApp'")
# Out:
#       review_id  user_id  app_name             app_category  \
# 121         122  5171208  WhatsApp                 Shopping
# 234         235  5522534  WhatsApp  Video Players & Editors
# 249         250  7203580  WhatsApp         Health & Fitness
# 282         283   540972  WhatsApp         Health & Fitness
# 327         328   214590  WhatsApp                 Business
# 485         486  4794689  WhatsApp            Music & Audio
# 509         510  1571723  WhatsApp            Communication
# 548         549  5113906  WhatsApp         Health & Fitness
# 619         620  1996774  WhatsApp                 Shopping
# 675         676  5665260  WhatsApp         Health & Fitness
# 728         729  6779508  WhatsApp                  Finance
# 810         811  8073718  WhatsApp                Education
# 827         828  2898595  WhatsApp         Health & Fitness
# 847         848  8895418  WhatsApp               Navigation
# 858         859  1966934  WhatsApp              Photography
# 903         904  2851363  WhatsApp                Education
# 933         934  8211313  WhatsApp            Entertainment
# 970         971  4383960  WhatsApp             Productivity
# 985         986  2447853  WhatsApp            Music & Audio
# 1082       1083  8823295  WhatsApp                Education
# 1107       1108  3515137  WhatsApp  Video Players & Editors
# 1154       1155  1669976  WhatsApp  Video Players & Editors
# 1168       1169  5140020  WhatsApp            Entertainment
# 1209       1210  8587536  WhatsApp            Communication
# 1305       1306  3388125  WhatsApp         Health & Fitness
# 1306       1307  4492083  WhatsApp        Social Networking
# 1316       1317  5998448  WhatsApp         News & Magazines
# 1323       1324  9212136  WhatsApp            Communication
# 1332       1333  7649276  WhatsApp                 Business
# 1334       1335  9788983  WhatsApp            Communication
# 1375       1376  2330219  WhatsApp            Entertainment
# 1376       1377  9915290  WhatsApp               Navigation
# 1410       1411  4269769  WhatsApp         Health & Fitness
# 1421       1422  3797296  WhatsApp               Navigation
# 1489       1490  3290758  WhatsApp                    Games
# 1499       1500   198836  WhatsApp                   Dating
# 1524       1525  1725497  WhatsApp        Social Networking
# 1652       1653  6656539  WhatsApp             Productivity
# 1791       1792  8257211  WhatsApp                   Dating
# 1793       1794  8840844  WhatsApp         Health & Fitness
# 1815       1816  7078813  WhatsApp               Navigation
# 1949       1950  9938645  WhatsApp                   Dating
# 1979       1980  5437828  WhatsApp        Social Networking
# 2003       2004  9884981  WhatsApp                Education
# 2029       2030  6298322  WhatsApp            Communication
# 2089       2090  1844250  WhatsApp        Social Networking
# 2115       2116  4693405  WhatsApp                    Games
# 2170       2171  3556607  WhatsApp                  Finance
# 2291       2292   773270  WhatsApp             Productivity
# 2315       2316  9236716  WhatsApp         News & Magazines
# 2317       2318  9172565  WhatsApp            Communication
# 2319       2320  2576873  WhatsApp                Utilities
# 2332       2333  5136779  WhatsApp                   Dating
# 2392       2393  7401331  WhatsApp         Health & Fitness
# 2402       2403  4772680  WhatsApp           Travel & Local
# 2404       2405  2895567  WhatsApp        Social Networking
# 2444       2445  5117805  WhatsApp                  Finance
# 2450       2451  1568345  WhatsApp                    Games
# 2502       2503  8102347  WhatsApp           Travel & Local
#
#                                             review_text review_language  \
# 121                                                 NaN              sv
# 234   Works perfectly on my device, no complaints at...              fi
# 249   Facere facere debitis distinctio veniam laboru...              en
# 282   The interface could be better but overall good...              th
# 327   Works perfectly on my device, no complaints at...              sv
# 485   Great app but too many ads, consider premium v...              pl
# 509              Кпсс головной интернет граница низкий.              en
# 548   Force si angoisse mort. Réussir plutôt page ca...              en
# 619   Perfect for daily use, highly recommend to eve...              tl
# 675   Perfect for daily use, highly recommend to eve...              nl
# 728                                                 NaN              th
# 810   Some bugs need fixing but generally satisfied ...              de
# 827   Excellent customer support and regular feature...              ja
# 847   Latest update broke some features, please fix ...              th
# 858   This app is amazing! Really love the new featu...              no
# 903   Excellent customer support and regular feature...              ar
# 933                 来自一下日本网络标题记者特别. 大小还有数据位置我们. 表示学校现在.              fi
# 970   Hic quo quibusdam quasi nihil deserunt exceptu...              es
# 985                     游戏系列学校. 朋友业务运行以上只要中文报告. 产品已经责任.              ms
# 1082  Recusandae dicta optio laudantium ea exercitat...              fi
# 1107  Eaque enim cum porro doloremque dolores. Delen...              en
# 1154  Sit debitis cumque magni earum. Distinctio vol...              it
# 1168  This app is amazing! Really love the new featu...              ko
# 1209                                                NaN              th
# 1305  Perfect for daily use, highly recommend to eve...              en
# 1306  Latest update broke some features, please fix ...              de
# 1316  Latest update broke some features, please fix ...              da
# 1323  Ab error reprehenderit quos illo. Reprehenderi...              vi
# 1332  Great app but too many ads, consider premium v...              de
# 1334  Empêcher quant à lever peser. Établir genre po...              de
# 1375  Cupiditate quis porro voluptate pariatur archi...              ms
# 1376  Great app but too many ads, consider premium v...              de
# 1410  Excellent customer support and regular feature...              pl
# 1421  Great app but too many ads, consider premium v...              th
# 1489  Excellent customer support and regular feature...              en
# 1499     楽しんで憲法ささやきシェービング改善状況隠す編組。 ソース運拡張同行省略。 風景ヘア建築癌。              vi
# 1524                           Placeat quo consectetur.              ar
# 1652  Mancare albergo attorno uso. Coscienza indietr...              ja
# 1791  Great app but too many ads, consider premium v...              zh
# 1793  This app is amazing! Really love the new featu...              th
# 1815  Odit soluta corporis eveniet. Ex illum officii...              es
# 1949  Perfect for daily use, highly recommend to eve...              ru
# 1979  Nauczyciel człowiek karta stolica. Pokazywać m...              da
# 2003  Deshalb allein Hase letzte vom. Hängen nämlich...              id
# 2029  Great app but too many ads, consider premium v...              ar
# 2089  Crashes too often, needs improvement in stabil...              ru
# 2115  Some bugs need fixing but generally satisfied ...              zh
# 2170  User-friendly design and smooth performance th...              ja
# 2291  Latest update broke some features, please fix ...              nl
# 2315  Crashes too often, needs improvement in stabil...              fi
# 2317                              Eum odit illum neque.              es
# 2319       Put imagine which beat education case under.              pl
# 2332  Hold decade investment operation long pass. Qu...              ko
# 2392  User-friendly design and smooth performance th...              ko
# 2402  Crashes too often, needs improvement in stabil...              th
# 2404  Great app but too many ads, consider premium v...              hi
# 2444  Great app but too many ads, consider premium v...              fi
# 2450  Dort Geld Brief. Bild auch ab werden steigen W...              pl
# 2502                                                NaN              ru
#
#       rating          review_date  verified_purchase     device_type  \
# 121      3.6  2023-08-11 20:49:22              False         Android
# 234      1.8  2025-06-02 03:48:27              False         Android
# 249      3.2  2023-11-15 17:28:56               True             iOS
# 282      3.4  2024-05-07 04:40:37               True             iOS
# 327      NaN  2024-02-19 10:28:05               True         Android
# 485      4.6  2023-10-12 03:13:14               True   Windows Phone
# 509      2.6  2025-04-14 22:34:30               True  Android Tablet
# 548      3.4  2025-04-30 18:46:59              False  Android Tablet
# 619      4.0  2023-11-11 19:16:23              False             iOS
# 675      3.5  2023-08-30 07:19:49               True   Windows Phone
# 728      4.0  2025-02-22 09:03:26               True  Android Tablet
# 810      3.4  2025-01-16 13:54:23               True  Android Tablet
# 827      4.7  2025-04-07 09:38:00               True            iPad
# 847      1.5  2024-02-08 03:26:01               True  Android Tablet
# 858      4.2  2024-03-24 20:53:28               True             iOS
# 903      3.8  2025-02-08 20:33:14              False            iPad
# 933      2.0  2024-07-28 12:16:34               True         Android
# 970      1.0  2024-06-15 07:18:40               True  Android Tablet
# 985      1.6  2023-09-03 03:11:57               True             iOS
# 1082     2.0  2024-09-28 10:48:52               True   Windows Phone
# 1107     4.5  2024-10-08 16:58:23               True             iOS
# 1154     4.4  2023-10-13 03:03:19               True         Android
# 1168     2.6  2025-05-15 12:28:59               True  Android Tablet
# 1209     4.7  2024-06-18 19:13:02              False   Windows Phone
# 1305     4.9  2023-08-17 13:43:08               True  Android Tablet
# 1306     2.9  2025-07-08 04:48:19               True   Windows Phone
# 1316     1.0  2024-01-26 15:53:58               True         Android
# 1323     3.5  2025-06-03 02:32:11               True  Android Tablet
# 1332     1.6  2025-05-24 09:06:34               True         Android
# 1334     4.5  2024-04-10 03:38:28               True            iPad
# 1375     2.9  2023-08-14 14:04:33               True             iOS
# 1376     2.4  2024-07-14 13:23:48               True             iOS
# 1410     3.8  2024-05-13 01:06:34               True            iPad
# 1421     1.4  2025-02-09 11:28:19               True  Android Tablet
# 1489     5.0  2025-07-08 09:13:54              False  Android Tablet
# 1499     3.7  2024-05-09 23:46:15               True             iOS
# 1524     4.9  2024-05-06 22:33:59              False   Windows Phone
# 1652     2.0  2024-04-23 03:31:42               True   Windows Phone
# 1791     1.5  2024-03-05 04:37:39               True         Android
# 1793     4.0  2024-01-26 22:34:47               True             iOS
# 1815     2.3  2023-10-22 09:23:18               True  Android Tablet
# 1949     4.1  2023-08-21 18:27:41               True         Android
# 1979     2.5  2025-02-27 15:36:29               True   Windows Phone
# 2003     1.2  2024-05-21 22:24:46               True            iPad
# 2029     3.0  2024-07-06 04:18:31               True   Windows Phone
# 2089     1.6  2025-03-29 10:31:06              False             iOS
# 2115     4.1  2023-08-21 08:26:58               True  Android Tablet
# 2170     2.0  2025-06-30 04:16:22              False             iOS
# 2291     2.5  2024-01-03 07:40:04               True  Android Tablet
# 2315     3.3  2023-12-06 04:17:51               True  Android Tablet
# 2317     2.0  2024-05-15 21:42:36               True             iOS
# 2319     3.0  2024-12-14 05:24:08               True   Windows Phone
# 2332     1.5  2024-04-29 21:27:24               True   Windows Phone
# 2392     4.4  2024-10-24 02:18:21               True             iOS
# 2402     3.7  2025-06-07 09:51:28               True         Android
# 2404     5.0  2024-09-08 04:03:01               True         Android
# 2444     2.9  2023-10-02 21:26:11               True            iPad
# 2450     3.3  2023-09-20 07:41:41               True            iPad
# 2502     4.6  2023-09-02 21:47:57               True  Android Tablet
#
#       num_helpful_votes  user_age    user_country        user_gender  \
# 121                  13      47.0           Spain  Prefer not to say
# 234                 140      71.0           China                NaN
# 249                 843      69.0           Spain  Prefer not to say
# 282                1120      30.0          Canada                NaN
# 327                 926      44.0         Nigeria               Male
# 485                 551      19.0  United Kingdom  Prefer not to say
# 509                 930      48.0         Vietnam         Non-binary
# 548                1194      13.0             NaN             Female
# 619                 635      16.0         Germany         Non-binary
# 675                 900      20.0        Malaysia         Non-binary
# 728                 163      56.0         Vietnam  Prefer not to say
# 810                1012      48.0           Spain         Non-binary
# 827                   0      40.0         Vietnam         Non-binary
# 847                   6      69.0          Canada             Female
# 858                 831      50.0     Philippines                NaN
# 903                 716      59.0             NaN               Male
# 933                 600      71.0         Germany  Prefer not to say
# 970                 103      18.0           Japan               Male
# 985                 267      58.0  United Kingdom  Prefer not to say
# 1082                163      13.0         Nigeria                NaN
# 1107                  4      16.0   United States               Male
# 1154                232      52.0        Malaysia             Female
# 1168                227      72.0        Thailand  Prefer not to say
# 1209                306      24.0           China                NaN
# 1305               1042      54.0          Turkey             Female
# 1306                288      13.0          France  Prefer not to say
# 1316                560      18.0  United Kingdom             Female
# 1323               1094      62.0           China         Non-binary
# 1332                863      62.0       Indonesia  Prefer not to say
# 1334                106      42.0   United States             Female
# 1375               1003      71.0       Indonesia                NaN
# 1376                  9      32.0           Japan               Male
# 1410                742      69.0     South Korea                NaN
# 1421                829      34.0           India                NaN
# 1489                891      19.0           Spain             Female
# 1499                163      53.0          France             Female
# 1524               1080      60.0          Russia  Prefer not to say
# 1652                751      43.0           China             Female
# 1791               1082      30.0     Philippines  Prefer not to say
# 1793                222      38.0           Spain                NaN
# 1815               1013      59.0          France                NaN
# 1949                536      57.0       Indonesia               Male
# 1979                748      34.0          Russia  Prefer not to say
# 2003               1059      74.0           Italy  Prefer not to say
# 2029                216      71.0        Malaysia  Prefer not to say
# 2089                990      67.0        Thailand         Non-binary
# 2115                389      42.0          Turkey             Female
# 2170                760      54.0       Australia                NaN
# 2291                742      60.0  United Kingdom             Female
# 2315                249      26.0           Italy               Male
# 2317                 25      36.0         Germany                NaN
# 2319                683      75.0           Spain                NaN
# 2332                330      37.0  United Kingdom  Prefer not to say
# 2392                526      62.0           India  Prefer not to say
# 2402                808      52.0       Australia         Non-binary
# 2404                121      66.0          France         Non-binary
# 2444                935      28.0      Bangladesh  Prefer not to say
# 2450                963      29.0          Canada             Female
# 2502                 19      51.0        Thailand                NaN
#
#        app_version
# 121     9.7.47.991
# 234        v2.4.99
# 249   13.7.38-beta
# 282    4.3.75-beta
# 327         1.0.60
# 485   13.4.28-beta
# 509      2.2.7.527
# 548         v7.5.2
# 619           11.5
# 675    8.5.24-beta
# 728          5.2.8
# 810        14.7.10
# 827        14.3.52
# 847   12.6.42-beta
# 858    7.1.18.9278
# 903    3.2.76-beta
# 933        v1.9.83
# 970       v11.2.23
# 985           12.0
# 1082        4.2.86
# 1107           2.2
# 1154           4.5
# 1168   7.0.67-beta
# 1209       v6.4.15
# 1305       v1.0.10
# 1306  11.6.52.8872
# 1316       v5.2.30
# 1323          13.5
# 1332      v10.2.72
# 1334  15.5.63-beta
# 1375   8.3.35.2822
# 1376           9.0
# 1410  10.6.66.5533
# 1421      v10.6.77
# 1489   8.6.37-beta
# 1499   5.3.39.5319
# 1524          11.1
# 1652           9.9
# 1791   1.8.78-beta
# 1793        8.5.15
# 1815      v10.4.87
# 1949   11.2.7-beta
# 1979       v5.1.47
# 2003   5.6.70-beta
# 2029    7.9.2-beta
# 2089  12.4.80.5785
# 2115   8.8.62-beta
# 2170       v2.5.81
# 2291       v1.2.50
# 2315      v15.3.35
# 2317      v12.2.62
# 2319           2.4
# 2332  12.0.76-beta
# 2392  12.8.10.4065
# 2402    2.2.7-beta
# 2404           2.6
# 2444          15.2
# 2450        6.9.19
# 2502        1.3.81

# %%
df.query("rating >= 3")
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating          review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09 19:26:40               True  Android Tablet
# 1        1.6  2024-06-21 17:29:40               True            iPad
# 2        3.6  2024-10-31 13:47:12               True            iPad
# 3        3.8  2025-03-12 06:16:22               True             iOS
# 4        3.2  2024-04-21 03:48:27               True            iPad
# ...      ...                  ...                ...             ...
# 2509     3.0  2023-11-23 01:07:30              False             iOS
# 2510     1.9  2025-06-05 16:42:20               True   Windows Phone
# 2511     3.4  2024-06-15 05:02:18               True  Android Tablet
# 2512     2.7  2023-12-02 01:41:31               True         Android
# 2513     2.1  2025-03-04 02:51:17               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  app_version
# 0                    65      14.0        China             Female          1.4
# 1                   209      18.0      Germany               Male          8.9
# 2                   163      67.0      Nigeria               Male  2.8.37.5926
# 3                   664      66.0        India             Female         10.2
# 4                  1197      40.0  South Korea  Prefer not to say          4.7
# ...                 ...       ...          ...                ...          ...
# 2509                635      21.0     Malaysia         Non-binary   1.1.2-beta
# 2510               1127      38.0   Bangladesh                NaN     v12.0.80
# 2511                677      27.0     Pakistan                NaN  9.1.32.4821
# 2512                155      35.0        India                NaN      v8.9.13
# 2513               1040      26.0   Bangladesh  Prefer not to say          2.2
#
# [2514 rows x 15 columns]

# %%
df['user_gender']
# Out:
# 0                  Female
# 1                    Male
# 2                    Male
# 3                  Female
# 4       Prefer not to say
#               ...
# 2509           Non-binary
# 2510                  NaN
# 2511                  NaN
# 2512                  NaN
# 2513    Prefer not to say
# Name: user_gender, Length: 2514, dtype: object

# %%
df['user_country']
# Out:
# 0             China
# 1           Germany
# 2           Nigeria
# 3             India
# 4       South Korea
#            ...
# 2509       Malaysia
# 2510     Bangladesh
# 2511       Pakistan
# 2512          India
# 2513     Bangladesh
# Name: user_country, Length: 2514, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review_id          2514 non-null   int64
#  1   user_id            2514 non-null   int64
#  2   app_name           2514 non-null   object
#  3   app_category       2514 non-null   object
#  4   review_text        2455 non-null   object
#  5   review_language    2514 non-null   object
#  6   rating             2477 non-null   float64
#  7   review_date        2514 non-null   object
#  8   verified_purchase  2514 non-null   bool
#  9   device_type        2514 non-null   object
#  10  num_helpful_votes  2514 non-null   int64
#  11  user_age           2514 non-null   float64
#  12  user_country       2473 non-null   object
#  13  user_gender        1927 non-null   object
#  14  app_version        2484 non-null   object
# dtypes: bool(1), float64(2), int64(3), object(9)
# memory usage: 277.6+ KB

# %%
df['device_type']
# Out:
# 0       Android Tablet
# 1                 iPad
# 2                 iPad
# 3                  iOS
# 4                 iPad
#              ...
# 2509               iOS
# 2510     Windows Phone
# 2511    Android Tablet
# 2512           Android
# 2513           Android
# Name: device_type, Length: 2514, dtype: object

# %%
df['review_date']
# Out:
# 0       2024-10-09 19:26:40
# 1       2024-06-21 17:29:40
# 2       2024-10-31 13:47:12
# 3       2025-03-12 06:16:22
# 4       2024-04-21 03:48:27
#                ...
# 2509    2023-11-23 01:07:30
# 2510    2025-06-05 16:42:20
# 2511    2024-06-15 05:02:18
# 2512    2023-12-02 01:41:31
# 2513    2025-03-04 02:51:17
# Name: review_date, Length: 2514, dtype: object

# %%
df.query("user_id == 1967825")['rating']
# Out:
# 0    1.3
# Name: rating, dtype: float64

# %%
df['user_country']
# Out:
# 0             China
# 1           Germany
# 2           Nigeria
# 3             India
# 4       South Korea
#            ...
# 2509       Malaysia
# 2510     Bangladesh
# 2511       Pakistan
# 2512          India
# 2513     Bangladesh
# Name: user_country, Length: 2514, dtype: object

# %%
df.isna().sum()
# Out:
# review_id              0
# user_id                0
# app_name               0
# app_category           0
# review_text           59
# review_language        0
# rating                37
# review_date            0
# verified_purchase      0
# device_type            0
# num_helpful_votes      0
# user_age               0
# user_country          41
# user_gender          587
# app_version           30
# dtype: int64

# %%
df['rating'].fillna(df['rating'].mean(),inplace=True)
df['user_gender'] = df['user_gender'].fillna('Others')
df['user_country'] = df['user_country'].fillna('Others')
df['app_version'].fillna(df['app_version'].mode()[0],inplace=True)
df['review_text'].fillna(df['review_text'].mode()[0],inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21168\1027519819.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].mean(),inplace=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21168\1027519819.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['app_version'].fillna(df['app_version'].mode()[0],inplace=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21168\1027519819.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['review_text'].fillna(df['review_text'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# review_id            0
# user_id              0
# app_name             0
# app_category         0
# review_text          0
# review_language      0
# rating               0
# review_date          0
# verified_purchase    0
# device_type          0
# num_helpful_votes    0
# user_age             0
# user_country         0
# user_gender          0
# app_version          0
# dtype: int64

# %%
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating          review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09 19:26:40               True  Android Tablet
# 1        1.6  2024-06-21 17:29:40               True            iPad
# 2        3.6  2024-10-31 13:47:12               True            iPad
# 3        3.8  2025-03-12 06:16:22               True             iOS
# 4        3.2  2024-04-21 03:48:27               True            iPad
# ...      ...                  ...                ...             ...
# 2509     3.0  2023-11-23 01:07:30              False             iOS
# 2510     1.9  2025-06-05 16:42:20               True   Windows Phone
# 2511     3.4  2024-06-15 05:02:18               True  Android Tablet
# 2512     2.7  2023-12-02 01:41:31               True         Android
# 2513     2.1  2025-03-04 02:51:17               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  app_version
# 0                    65      14.0        China             Female          1.4
# 1                   209      18.0      Germany               Male          8.9
# 2                   163      67.0      Nigeria               Male  2.8.37.5926
# 3                   664      66.0        India             Female         10.2
# 4                  1197      40.0  South Korea  Prefer not to say          4.7
# ...                 ...       ...          ...                ...          ...
# 2509                635      21.0     Malaysia         Non-binary   1.1.2-beta
# 2510               1127      38.0   Bangladesh             Others     v12.0.80
# 2511                677      27.0     Pakistan             Others  9.1.32.4821
# 2512                155      35.0        India             Others      v8.9.13
# 2513               1040      26.0   Bangladesh  Prefer not to say          2.2
#
# [2514 rows x 15 columns]

# %%
df['review_date'] = pd.to_datetime(df['review_date']).dt.date
df['review_time'] = pd.to_datetime(df['review_date']).dt.time
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09               True  Android Tablet
# 1        1.6  2024-06-21               True            iPad
# 2        3.6  2024-10-31               True            iPad
# 3        3.8  2025-03-12               True             iOS
# 4        3.2  2024-04-21               True            iPad
# ...      ...         ...                ...             ...
# 2509     3.0  2023-11-23              False             iOS
# 2510     1.9  2025-06-05               True   Windows Phone
# 2511     3.4  2024-06-15               True  Android Tablet
# 2512     2.7  2023-12-02               True         Android
# 2513     2.1  2025-03-04               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  \
# 0                    65      14.0        China             Female
# 1                   209      18.0      Germany               Male
# 2                   163      67.0      Nigeria               Male
# 3                   664      66.0        India             Female
# 4                  1197      40.0  South Korea  Prefer not to say
# ...                 ...       ...          ...                ...
# 2509                635      21.0     Malaysia         Non-binary
# 2510               1127      38.0   Bangladesh             Others
# 2511                677      27.0     Pakistan             Others
# 2512                155      35.0        India             Others
# 2513               1040      26.0   Bangladesh  Prefer not to say
#
#       app_version review_time
# 0             1.4    00:00:00
# 1             8.9    00:00:00
# 2     2.8.37.5926    00:00:00
# 3            10.2    00:00:00
# 4             4.7    00:00:00
# ...           ...         ...
# 2509   1.1.2-beta    00:00:00
# 2510     v12.0.80    00:00:00
# 2511  9.1.32.4821    00:00:00
# 2512      v8.9.13    00:00:00
# 2513          2.2    00:00:00
#
# [2514 rows x 16 columns]

# %%
df['user_age']=df['user_age'].astype('int')

# %%
df=df.drop(columns=['review_time'])

# %%
df['review_id'].unique()
df
# Out:
#       review_id  user_id      app_name       app_category  \
# 0             1  1967825     MX Player     Travel & Local
# 1             2  9242600        Tinder         Navigation
# 2             3  7636477       Netflix             Dating
# 3             4   209031         Venmo       Productivity
# 4             5  7190293  Google Drive          Education
# ...         ...      ...           ...                ...
# 2509       2510  2322118      OneDrive           Business
# 2510       2511  2167693        Signal            Finance
# 2511       2512  5554467      OneDrive  Social Networking
# 2512       2513  8805125      Coursera  Social Networking
# 2513       2514  1099793         Venmo          Education
#
#                                             review_text review_language  \
# 0     Qui doloribus consequuntur. Perspiciatis tempo...              no
# 1     Great app but too many ads, consider premium v...              ru
# 2     The interface could be better but overall good...              es
# 3     Latest update broke some features, please fix ...              vi
# 4     Perfect for daily use, highly recommend to eve...              tl
# ...                                                 ...             ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...              nl
# 2510  This app is amazing! Really love the new featu...              ms
# 2511  This app is amazing! Really love the new featu...              zh
# 2512  Invitare convincere pericoloso corsa fortuna. ...              da
# 2513  Latest update broke some features, please fix ...              it
#
#       rating review_date  verified_purchase     device_type  \
# 0        1.3  2024-10-09               True  Android Tablet
# 1        1.6  2024-06-21               True            iPad
# 2        3.6  2024-10-31               True            iPad
# 3        3.8  2025-03-12               True             iOS
# 4        3.2  2024-04-21               True            iPad
# ...      ...         ...                ...             ...
# 2509     3.0  2023-11-23              False             iOS
# 2510     1.9  2025-06-05               True   Windows Phone
# 2511     3.4  2024-06-15               True  Android Tablet
# 2512     2.7  2023-12-02               True         Android
# 2513     2.1  2025-03-04               True         Android
#
#       num_helpful_votes  user_age user_country        user_gender  app_version
# 0                    65        14        China             Female          1.4
# 1                   209        18      Germany               Male          8.9
# 2                   163        67      Nigeria               Male  2.8.37.5926
# 3                   664        66        India             Female         10.2
# 4                  1197        40  South Korea  Prefer not to say          4.7
# ...                 ...       ...          ...                ...          ...
# 2509                635        21     Malaysia         Non-binary   1.1.2-beta
# 2510               1127        38   Bangladesh             Others     v12.0.80
# 2511                677        27     Pakistan             Others  9.1.32.4821
# 2512                155        35        India             Others      v8.9.13
# 2513               1040        26   Bangladesh  Prefer not to say          2.2
#
# [2514 rows x 15 columns]

# %%
df['user_age']
# Out:
# 0       14
# 1       18
# 2       67
# 3       66
# 4       40
#         ..
# 2509    21
# 2510    38
# 2511    27
# 2512    35
# 2513    26
# Name: user_age, Length: 2514, dtype: int64

# %%
df['user_gender']
# Out:
# 0                  Female
# 1                    Male
# 2                    Male
# 3                  Female
# 4       Prefer not to say
#               ...
# 2509           Non-binary
# 2510               Others
# 2511               Others
# 2512               Others
# 2513    Prefer not to say
# Name: user_gender, Length: 2514, dtype: object

# %%
plt.figure(figsize=(10,5))
col=['review_id',	'user_id','rating','num_helpful_votes',	'user_age']
sns.heatmap(df[col].corr(),annot=True)
# Out:
# <Axes: >

# %%
df[col].corr()
# Out:
#                    review_id   user_id    rating  num_helpful_votes  user_age
# review_id           1.000000 -0.010945  0.009411           0.026026  0.000517
# user_id            -0.010945  1.000000 -0.001533          -0.026070 -0.007048
# rating              0.009411 -0.001533  1.000000           0.009364  0.017086
# num_helpful_votes   0.026026 -0.026070  0.009364           1.000000 -0.009778
# user_age            0.000517 -0.007048  0.017086          -0.009778  1.000000

# %% [markdown]
# review_id → Unique identifier for each review.
#
# user_id → Unique identifier for the user who wrote the review.
#
# app_name → Name of the mobile application being reviewed.
#
# app_category → Category/genre of the app (e.g., Games, Finance, Health).
#
# review_text → Written text of the user’s review.
#
# review_language → Language in which the review is written.
#
# rating → Star rating or numeric score given by the user.
#
# review_date → Date when the review was submitted.
#
# verified_purchase → Whether the review is from a verified purchase (Yes/No).
#
# device_type → Type of device used (e.g., Android, iOS, Tablet).
#
# num_helpful_votes → Number of people who found the review helpful.
#
# user_age → Age of the user writing the review.
#
# user_country → Country of the user.
#
# user_gender → Gender of the user.
#
# app_version → Version of the app being reviewed.

# %%
plt.figure(figsize=(10, 5))
lang_counts = df["review_language"].value_counts().head(10)
sns.barplot(x=lang_counts.index, y=lang_counts.values)
plt.title("Top 10 Review Languages", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Top 10 Review Languages')

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(data=df, x="verified_purchase", y="rating")
plt.title("Ratings by Verified Purchase Status")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.barplot(df,x='device_type',y='rating')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df,x='user_gender',y='rating')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x="app_category", y="rating")
plt.title("Ratings Distribution by App Category")
plt.show()

# %% [markdown]
# # make observation
#
#
#
# 1. Which factors do you think most strongly influence the rating of an app? Why?
# 2. How might review_language affect the interpretation of user satisfaction?
# 3. Explain how app_version and review_date together can show app improvement or decline.
# 4. Do you think verified_purchase makes reviews more trustworthy? Justify your answer.
# 5. How would you test whether device_type has an impact on app ratings?
# 6. If you had to find which age group is most satisfied, what steps would you follow?
# 7. How would you identify fake or unreliable reviews using num_helpful_votes and review_text?

# %% [markdown]
# # coclusion:
#
# The target is to find out what factors (language, gender, age, purchase status, category, version, device, etc.) most influence user ratings and satisfaction

# %% [markdown]
# 1. Suppose you are an app developer: what insights from this dataset would help you improve
# your app?
# 2. Propose one machine learning project idea using this dataset and describe its expected
# outcome

# %% [markdown]
# # language reference
#
#
#
# | Code   | Language           |
# | ------ | ------------------ |
# | **no** | Norwegian          |
# | **ru** | Russian            |
# | **es** | Spanish            |
# | **vi** | Vietnamese         |
# | **tl** | Tagalog (Filipino) |
# | **th** | Thai               |
# | **da** | Danish             |
# | **ja** | Japanese           |
# | **ms** | Malay              |
# | **fr** | French             |
# | **it** | Italian            |
# | **nl** | Dutch              |
# | **hi** | Hindi              |
# | **ar** | Arabic             |
# | **zh** | Chinese            |
# | **id** | Indonesian         |
# | **pl** | Polish             |
# | **ko** | Korean             |
# | **sv** | Swedish            |
# | **pt** | Portuguese         |
# | **tr** | Turkish            |
# | **fi** | Finnish            |
# | **de** | German             |
# | **en** | English            |
